# %%
import os
os.getcwd()
# Out:
# 'C:\\Documents and Settings\\Kevin'

# %%
# preliminaries

import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
pd.set_option('max_columns', 50)
from numpy.random import normal

# %%
### Generate 1000 Random Numbers

# %%
gaussian_numbers = normal(size=1000)

print( np.mean(gaussian_numbers) )
print( np.var(gaussian_numbers) )
# Out:
# 0.0233267382145
# 0.974132737062

# %%
plt.hist(gaussian_numbers)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
plt.hist(gaussian_numbers, bins=20)
# Out:
# (array([   5.,    6.,    8.,   17.,   33.,   53.,   79.,   99.,  116.,
#          120.,  138.,  111.,   81.,   63.,   27.,   17.,   13.,    9.,
#            3.,    2.]),
#  array([-3.00847492, -2.69338702, -2.37829912, -2.06321122, -1.74812332,
#         -1.43303542, -1.11794752, -0.80285961, -0.48777171, -0.17268381,
#          0.14240409,  0.45749199,  0.77257989,  1.08766779,  1.40275569,
#          1.71784359,  2.03293149,  2.34801939,  2.66310729,  2.97819519,
#          3.29328309]),
#  <a list of 20 Patch objects>)

# %%
plt.hist(gaussian_numbers, bins=20, normed=True, cumulative=True)
# Out:
# (array([ 0.005,  0.011,  0.019,  0.036,  0.069,  0.122,  0.201,  0.3  ,
#          0.416,  0.536,  0.674,  0.785,  0.866,  0.929,  0.956,  0.973,
#          0.986,  0.995,  0.998,  1.   ]),
#  array([-3.00847492, -2.69338702, -2.37829912, -2.06321122, -1.74812332,
#         -1.43303542, -1.11794752, -0.80285961, -0.48777171, -0.17268381,
#          0.14240409,  0.45749199,  0.77257989,  1.08766779,  1.40275569,
#          1.71784359,  2.03293149,  2.34801939,  2.66310729,  2.97819519,
#          3.29328309]),
#  <a list of 20 Patch objects>)

# %%
import matplotlib.pyplot as plt
from numpy.random import normal, uniform
gaussian_numbers = normal(size=1000)
uniform_numbers = uniform(low=-3, high=3, size=1000)
plt.hist(gaussian_numbers, bins=20, histtype='stepfilled', normed=True, color='b', label='Gaussian')
plt.hist(uniform_numbers, bins=20, histtype='stepfilled', normed=True, color='r', alpha=0.5, label='Uniform')
plt.title("Gaussian/Uniform Histogram")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.legend()
plt.show()
